# %%
import pandas as pd

# %%
dataframe=pd.read_csv("warmupdata/coffee.csv")

# %%
print(dataframe.columns) #Columns
print(dataframe.index)#Indices
print(dataframe.nunique())#Number of unique values per column

#Get the dataframe info
print("    ")
print("Dataframe")
dataframe.info()

#Get the dataframe statistics
print("    ")
print("Dataframe statistics")
dataframe.describe()
# Out:
# Index(['Day', 'Coffee Type', 'Units Sold'], dtype='object')
# RangeIndex(start=0, stop=14, step=1)
# Day            7
# Coffee Type    2
# Units Sold     7
# dtype: int64
#
# Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes
#
# Dataframe statistics
#        Units Sold
# count   14.000000
# mean    32.857143
# std      9.346798
# min     15.000000
# 25%     26.250000
# 50%     35.000000
# 75%     38.750000
# max     45.000000
